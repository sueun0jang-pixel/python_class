# %% [markdown]
# ## datatype2.py
# ##### 이름과 나이, 키(소수점 1자리), 결혼여부(기혼 : True, 미혼 : False)

# %%
name = '김민경'
age = 31
height = 163
is_mariage = False

print(f'user_name : {name}')
print(f'age : {age}')
print(f'height : {height}')
print(f'is_mariage : {is_mariage}')

a = input(str('결혼여부를 작성해주세요'))
b = ""

if a == '아니오' :
    c = is_mariage
    print(c)
elif a == '네' :
    is_mariage = True
    c = is_mariage
    print(c)
# Out:
# user_name : 김민경
# age : 31
# height : 163
# is_mariage : False
