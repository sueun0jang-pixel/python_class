# %% [markdown]
# ## string4.py
# ##### 문자열의 길이 (len)을 구하는 예제

# %%
str = 'hello'

length = len(str)
print(f'str 문자열의 길이 : {length}')
# Out:
# str 문자열의 길이 : 5

# %%
str1 = 'hello'

print(f'str1 문자열의 길이 : {len(str1)}')
print(f'str1 문자열의 길이 : {len(str1.strip())}')
# Out:
# str1 문자열의 길이 : 5
# str1 문자열의 길이 : 5
