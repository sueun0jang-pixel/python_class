# %% [markdown]
# ## for1.py
# ##### 반복문에 대한 예제 프로그램입니다.
# ##### 시퀀스 자료형 : 문자열, 리스트, 튜플

# %%
str = 'abcdefg'

print(f'str : {str}')
print(f'str 자료형 : {type(str)}')

for ch in str:
    print(ch)
# Out:
# str : abcdefg
# str 자료형 : <class 'str'>
# a
# b
# c
# d
# e
# f
# g
