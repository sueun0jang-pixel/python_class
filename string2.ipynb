# %% [markdown]
# ## String2.py
# ##### 키보드를 사용하여 점수를 입력 받아서 출력하는 프로그램입니다.

# %%
score = input('점수를 입력하세요.')

print(f'score : {score}')
print(f'score 자료형 : {type(score)}')
# Out:
# score : 5
# score 자료형 : <class 'str'>

# %%
line = '=' *100
print(line)

a = 14.5
print(int(a))

num_str = '1234.567'
print(float(num_str))
print(f'num_str : {float(num_str):.2f}')

b = 'python'
# print(int(num_str)) -> 문자를 숫자로 변경할 수 없기 때문에 에러가 뜸
# Out:
# ...
# 14
# 1234.567
# num_str : 1234.57
