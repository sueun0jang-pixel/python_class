# %% [markdown]
# ## operator6.py
# ##### 논리 연산자에 대한 예제 프로그램입니다.

# %%
score = 90

result = 0 <= score <= 100
print(result)
# Out:
# True

# %%
score = 90

result = score >= 0 and score <= 100
print(result)

result = score < 0 or score > 100
print(result)
# Out:
# True
# False

# %%
flag = True

result = not flag
print(result)
# Out:
# False
