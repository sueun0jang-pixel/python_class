# %% [markdown]
# ## exam2_1.py
# ##### 사용자로부터 두 수를 입력 받아 둘 중에서 큰 수를 출력하는 프로그램입니다.
# ##### 조건 연산자 사용할 것!!

# %%
user_num1, user_num2 = list(map(int, input("숫자를 입력해주세요").split()))

if user_num1 > user_num2:
    print(f"큰 수는 {user_num1}입니다.")
else:
    print(f"큰 수는 {user_num2}입니다.")
# Out:
# 10 20
# 큰 수는 20입니다.
