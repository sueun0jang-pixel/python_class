# %% [markdown]
# ## operator2.py
# ##### 대입 연산자에 대한 예제 프로그램입니다.

# %%
a, b = 1, 2

result = a + 1
temp = b

print(f'a : {a}')
print(f'b : {b}')
print(f'result : {result}')
print(f'temp : {temp}')
# Out:
# a : 1
# b : 2
# result : 2
# temp : 2

# %%
x, y = 10, 20

x= x + y
print(f'x = {x}, y = {y}')
# Out:
# x = 30, y = 20
