# %% [markdown]
# ## datatype3.py
# ##### constant(상수) -> 대문자로 작성하기

# %%
PI = 3.141592
print(f'PI : {PI}')

PI = 3.14
print(f'PI : {PI}')
# Out:
# PI : 3.141592
# PI : 3.14

# %%
##### 값이 없는 상태

# %%
temp = None

print(f'temp {temp}')
print(f'temp 자료형" {type(temp)}')
# Out:
# temp None
# temp 자료형" <class 'NoneType'>
