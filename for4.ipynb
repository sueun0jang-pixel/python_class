# %% [markdown]
# # for4.py

# %%
adj = ['small', 'medium', 'large']
nouns = ['apple', 'banana', 'grape']

for x in adj:
    for j in nouns:
        print(x,j)
# Out:
# small apple
# small banana
# small grape
# medium apple
# medium banana
# medium grape
# large apple
# large banana
# large grape
