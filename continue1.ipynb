# %% [markdown]
# ## continue1.py

# %%
for i in range(1, 11, 1):
    if i % 3 == 0:
        continue
    print(i)
# Out:
# 1
# 2
# 4
# 5
# 7
# 8
# 10

# %%
# 사용자로부터 '-'가 포함된 계좌번호를 입력 받아 '-'를 삭제한 문자열 출력

user_acount = input("계좌번호를 입력해주세요.")
list = ''

for i in user_acount:
    if i == "-":
        continue
    list += i

print(list)
# Out:
# 100200300
