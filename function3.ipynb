# %% [markdown]
# ## function3.py
# ##### 사용자 정의 함수에 대한 예제 프로그램입니다.
# ##### 두 정수의 합을 구하는 함수(sum)를 정의하여 호출해보세요.

# %%
def sum_function (x, y):
    sum_total = x + y
    return sum_total

result = sum_function(2,3)
print(result)
# Out:
# 5
