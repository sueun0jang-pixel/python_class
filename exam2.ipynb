# %% [markdown]
# ## exam2.py
# ##### 실습문제 2

# %%
# 두 수 50과 100의 사칙연산을 +, -, * , / (산술연산자)를 이용해 구하고 연산결과 값을 화면에 출력하세요.
a, b = 50, 100

print(f'a + b : {a+b}')
print(f'a - b : {a-b}')
print(f'a * b : {a*b}')
print(f'a / b : {a/b}')
# Out:
# a + b : 150
# a - b : -50
# a * b : 5000
# a / b : 0.5

# %%
#첫번째 변수에 'python is'를 저장하고, 두번째 변수에 'easy'를 사용자에게 입력받아 'python is easy'를 화면에 출력하세요.

defalut_value = "python is"
user_value = input("easy를 입력하세요")

print(defalut_value,end=" ")
print(user_value)
# Out:
# python is

# %%
# 가로와 세로의 길이를 입력 받아서 사각형의 넓이를 계산하는 프로그램을 작성하세요.

width = float(input("가로 길이를 입력하세요."))
height = float(input("세로 길이를 입력하세요."))

area = width * height

print(f'사각형의 넓이는 : {area:.2f} 입니다.')
# Out:
# 사각형의 넓이는 : 612.56 입니다.

# %%
# 초 단위의 시간을 입력 받아서 몇 분 몇 초인지 계산하여 출력하세요.

input_second = int(input("계산이 필요한 초 단위를 입력하세요."))

minute = int(input_second//60)
second = int(input_second%60)

print(f'{input_second}초는 {minute}분 {second}초 입니다. ')
# Out:
# 50초는 0분 50초 입니다.

# %%
# 가지고 있는 돈으로 가격이 120원인 사탕을 최대한 몇 개까지 살 수 있는지 계산하고, 나머지 돈은 얼마인지 나타내시오.

money = int(input("가지고 있는 돈을 입력하세요."))
candy_price = 120

candy_count = money // candy_price
remaining_money = money % candy_price

print(f'사탕을 {candy_count}개 살 수 있습니다.', end=" ")
print(f'남은 돈은 {remaining_money}원 입니다.')
# Out:
# 사탕을 16개 살 수 있습니다. 남은 돈은 80원 입니다.
