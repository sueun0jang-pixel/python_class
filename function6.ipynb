# %% [markdown]
# ## function6.py
# ##### 디폴트 인수

# %%
# 함수 정의
def greet(name, msg):
    print(f'{msg}, {name}')

#함수 호출
greet('철수', '좋은아침')
greet('철수') # 디폴트 인수인 msg가 필요함
# Out:
# 좋은아침, 철수
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 7
#       5 #함수 호출
#       6 greet('철수', '좋은아침')
# ----> 7 greet('철수')
#
# TypeError: greet() missing 1 required positional argument: 'msg'
