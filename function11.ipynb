# %% [markdown]
# ## function11.py
# ##### 언패킹에 대한 예제 프로그램입니다.

# %%
# 함수 정의

def print_all(a, b, c):
    print(f'a={a}, b={b}, c={c}')

_list = [1, 2, 3]
print_all(*_list) # print_all(1, 2, 3) : 언패킹
print_all(_list) # print_all([1, 2, 3]) 인자가 리스트 형태로 가기 때문에 에러가 발생함
# Out:
# a=1, b=2, c=3
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 8
#       6 _list = [1, 2, 3]
#       7 print_all(*_list) # print_all(1, 2, 3) : 언패킹
# ----> 8 print_all(_list)
#
# TypeError: print_all() missing 2 required positional arguments: 'b' and 'c'
