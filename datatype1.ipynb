# %% [markdown]
# ## datatype 연습

# %%
# 숫자형

a = 10
b = 4.5

print(a)
print(b)

print(type(a))
print(type(b))

flag = True

print(flag)
print(type(flag))

str = "Hello"

print(str)
print(type(str))
# Out:
# 10
# 4.5
# <class 'int'>
# <class 'float'>
# True
# <class 'bool'>
# Hello
# <class 'str'>
