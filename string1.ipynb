# %% [markdown]
# ## String1.py
# ##### 문자열에 대한 내용입니다.

# %%
introduce = """안녕하세요.
만나서 반갑습니다."""


print(introduce)
print("철수가 '안녕' 이라고 말했습니다.")
# Out:
# 안녕하세요.
# 만나서 반갑습니다.
# 철수가 '안녕' 이라고 말했습니다.

# %%
print(100 + 200)
print("100" + "200")

num = str(10)
print("num :" + num)
# Out:
# 300
# 100200
# num :10
