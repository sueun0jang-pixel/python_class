# %% [markdown]
# # for3.py
# # 중첩 반복문에 대한 예제 프로그램입니다.

# %%
for x in range(1, 6, 1):
    for y in range(1, 3):
        print(f'{x} : {y}')
# Out:
# 1 : 1
# 1 : 2
# 2 : 1
# 2 : 2
# 3 : 1
# 3 : 2
# 4 : 1
# 4 : 2
# 5 : 1
# 5 : 2
