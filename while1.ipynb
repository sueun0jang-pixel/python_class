# %% [markdown]
# ## while1.py
# ##### 투자금이 2배가 되는데 걸리는 시간 계산

# %%
target = 2000
money = 1000
year = 0
rate = 0.07

while money < target:
    money += money * 0.07
    year += 1
    print(f'money : {money}, year : {year}')
# Out:
# money : 1070.0, year : 1
# money : 1144.9, year : 2
# money : 1225.0430000000001, year : 3
# money : 1310.79601, year : 4
# money : 1402.5517307, year : 5
# money : 1500.730351849, year : 6
# money : 1605.78147647843, year : 7
# money : 1718.18617983192, year : 8
# money : 1838.4592124201545, year : 9
# money : 1967.1513572895653, year : 10
# money : 2104.851952299835, year : 11

# %%
user_num = int(input('원하는 단을 입력해주세요.'))

i = 1

while i <= 9:
    print(f'{user_num} * {i} = {user_num*i}')
    i += 1
# Out:
# 9 * 1 = 9
# 9 * 2 = 18
# 9 * 3 = 27
# 9 * 4 = 36
# 9 * 5 = 45
# 9 * 6 = 54
# 9 * 7 = 63
# 9 * 8 = 72
# 9 * 9 = 81
