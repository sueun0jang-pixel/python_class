# %% [markdown]
# ## function4.py
# ##### 원의 면적을 구하는 함수 정의

# %%
def get_area(x):
    return 3.14*x

user_num = int(input('반지름 값을 입력해주세요.'))
result = get_area(user_num)
print(f'반지름 {user_num}cm의 원의 면적은 {result:.2f}입니다.')
# Out:
# 반지름 10cm의 원의 면적은 31.40입니다.
